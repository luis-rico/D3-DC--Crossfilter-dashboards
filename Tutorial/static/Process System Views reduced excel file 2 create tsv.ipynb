# %%
import pandas as pd
import datetime

xl_file = pd.ExcelFile("System Views Faults reduced.xlsx")

DfData = xl_file.parse("Review Faults - 1051", header=0)

DfData.head()
# Out:
#   Set_ID  Fault_ID  RC_Fault_ID               Classification  \
# 0    A19      8375       115880      Passenger Bodyside Door
# 1    A19      8375       115880      Passenger Bodyside Door
# 2    A49     55509       242542  Digital Voice Announcements
# 3    A48     55508       242541                    Batteries
# 4     A8     55507       242540                      Windows
#
#   Fault_Reported_Date   WO_Num WO_Car  Num_Faults
# 0 2012-11-14 14:09:44   283628  N5519           1
# 1 2012-11-14 14:09:44   283628  N5519           1
# 2 2015-01-15 05:40:18  1088552  D6449           1
# 3 2015-01-15 05:34:20  1088551  D6348           1
# 4 2015-01-15 05:19:53  1088550  D6408           1

# %%
DfData.to_csv('SystemViewsFaultsreduced_LHR_01.tsv', sep='\t')

# %%
DfData
# Out:
#      Set_ID  Fault_ID  RC_Fault_ID  \
# 0       A19      8375       115880
# 1       A19      8375       115880
# 2       A49     55509       242542
# 3       A48     55508       242541
# 4        A8     55507       242540
# 5       A36     55506       242539
# 6       A66     55505       242518
# 7       A41     55503       242513
# 8       A41     55502       242512
# 9       A27     55501       242628
# 10      A56     55500       242511
# 11      A61     55499       242617
# 12      A61     55498       242616
# 13      NaN     55498          NaN
# 14      A33     55496       242614
# 15      A78     55495       242613
# 16      A51     55494       242612
# 17      A51     55493       242611
# 18      A51     55492       242610
# 19      A33     55491       242604
# 20      A36     55489       242601
# 21      A26     55488       242600
# 22      A26     55487       242599
# 23      A16     55486       242597
# 24      A78     55483       242589
# ...
